# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('taxi_trip_pricing.csv')

# %%
df
# Out:
#      Trip_Distance_km Time_of_Day Day_of_Week  Passenger_Count  \
# 0               19.35     Morning     Weekday              3.0
# 1               47.59   Afternoon     Weekday              1.0
# 2               36.87     Evening     Weekend              1.0
# 3               30.33     Evening     Weekday              4.0
# 4                 NaN     Evening     Weekday              3.0
# ..                ...         ...         ...              ...
# 995              5.49   Afternoon     Weekend              4.0
# 996             45.95       Night     Weekday              4.0
# 997              7.70     Morning     Weekday              3.0
# 998             47.56     Morning     Weekday              1.0
# 999             22.85     Morning     Weekend              3.0
#
#     Traffic_Conditions Weather  Base_Fare  Per_Km_Rate  Per_Minute_Rate  \
# 0                  Low   Clear       3.56         0.80             0.32
# 1                 High   Clear        NaN         0.62             0.43
# 2                 High   Clear       2.70         1.21             0.15
# 3                  Low     NaN       3.48         0.51             0.15
# 4                 High   Clear       2.93         0.63             0.32
# ..                 ...     ...        ...          ...              ...
# 995             Medium   Clear       2.39         0.62             0.49
# 996             Medium   Clear       3.12         0.61              NaN
# 997                Low    Rain       2.08         1.78              NaN
# 998                Low   Clear       2.67         0.82             0.17
# 999             Medium   Clear       4.34          NaN             0.23
#
#      Trip_Duration_Minutes  Trip_Price
# 0                    53.82     36.2624
# 1                    40.57         NaN
# 2                    37.27     52.9032
# 3                   116.81     36.4698
# 4                    22.64     15.6180
# ..                     ...         ...
# 995                  58.39     34.4049
# 996                  61.96     62.1295
# 997                  54.18     33.1236
# 998                 114.94     61.2090
# 999                  29.69     45.4437
#
# [1000 rows x 11 columns]

# %%
df.describe()
# Out:
#        Trip_Distance_km  Passenger_Count   Base_Fare  Per_Km_Rate  \
# count        950.000000       950.000000  950.000000   950.000000
# mean          27.070547         2.476842    3.502989     1.233316
# std           19.905300         1.102249    0.870162     0.429816
# min            1.230000         1.000000    2.010000     0.500000
# 25%           12.632500         1.250000    2.730000     0.860000
# 50%           25.830000         2.000000    3.520000     1.220000
# 75%           38.405000         3.000000    4.260000     1.610000
# max          146.067047         4.000000    5.000000     2.000000
#
#        Per_Minute_Rate  Trip_Duration_Minutes  Trip_Price
# count       950.000000             950.000000  951.000000
# mean          0.292916              62.118116   56.874773
# std           0.115592              32.154406   40.469791
# min           0.100000               5.010000    6.126900
# 25%           0.190000              35.882500   33.742650
# 50%           0.290000              61.860000   50.074500
# 75%           0.390000              89.055000   69.099350
# max           0.500000             119.840000  332.043689

# %%
df[df['Trip_Distance_km'].isnull()]
# Out:
#      Trip_Distance_km Time_of_Day Day_of_Week  Passenger_Count  \
# 4                 NaN     Evening     Weekday              3.0
# 10                NaN     Morning     Weekday              4.0
# 84                NaN       Night     Weekday              1.0
# 87                NaN         NaN     Weekday              1.0
# 95                NaN     Morning     Weekend              1.0
# 111               NaN     Morning     Weekday              2.0
# 134               NaN   Afternoon     Weekend              3.0
# 137               NaN         NaN         NaN              3.0
# 142               NaN   Afternoon     Weekend              4.0
# 166               NaN     Evening     Weekday              2.0
# 191               NaN   Afternoon     Weekend              2.0
# 196               NaN       Night     Weekday              2.0
# 197               NaN       Night     Weekend              3.0
# 234               NaN   Afternoon     Weekday              3.0
# 269               NaN     Morning     Weekday              3.0
# 282               NaN   Afternoon     Weekday              1.0
# 327               NaN     Evening     Weekday              3.0
# 344               NaN     Evening         NaN              NaN
# 357               NaN   Afternoon     Weekday              3.0
# 366               NaN     Evening     Weekday              4.0
# 401               NaN     Morning         NaN              1.0
# 404               NaN   Afternoon     Weekday              2.0
# 417               NaN     Morning     Weekday              3.0
# 424               NaN       Night     Weekday              1.0
# 428               NaN   Afternoon     Weekday              NaN
# 438               NaN     Morning     Weekday              2.0
# 439               NaN   Afternoon     Weekday              4.0
# 446               NaN   Afternoon     Weekday              1.0
# 470               NaN   Afternoon     Weekday              3.0
# 476               NaN     Evening     Weekday              NaN
# 584               NaN       Night     Weekday              4.0
# 641               NaN     Evening     Weekday              4.0
# 647               NaN     Evening     Weekday              2.0
# 725               NaN     Morning     Weekday              1.0
# 734               NaN     Morning     Weekend              1.0
# 770               NaN   Afternoon     Weekday              1.0
# 774               NaN     Evening     Weekday              1.0
# 796               NaN     Evening     Weekday              NaN
# 813               NaN     Morning     Weekday              3.0
# 822               NaN   Afternoon     Weekday              1.0
# 830               NaN       Night     Weekday              3.0
# 839               NaN     Morning     Weekday              3.0
# 845               NaN     Morning     Weekday              4.0
# 846               NaN     Morning     Weekend              4.0
# 872               NaN   Afternoon         NaN              4.0
# 939               NaN     Morning     Weekday              2.0
# 943               NaN     Evening     Weekend              1.0
# 961               NaN   Afternoon     Weekday              2.0
# 970               NaN     Morning     Weekday              4.0
# 993               NaN     Morning     Weekday              3.0
#
#     Traffic_Conditions Weather  Base_Fare  Per_Km_Rate  Per_Minute_Rate  \
# 4                 High   Clear       2.93         0.63             0.32
# 10                 NaN   Clear       2.40         0.58             0.43
# 84              Medium   Clear       3.38         1.50             0.31
# 87              Medium   Clear       3.41         0.57             0.39
# 95              Medium   Clear       3.43         0.91             0.50
# 111                Low   Clear       4.01         1.65             0.17
# 134                Low   Clear       2.55         1.46             0.37
# 137                Low   Clear       4.52         1.38             0.35
# 142             Medium    Rain       2.98         1.24             0.28
# 166               High   Clear       4.11         1.00             0.36
# 191             Medium   Clear       2.47         0.83             0.45
# 196               High   Clear       3.34         1.49             0.27
# 197             Medium   Clear       3.22         1.03             0.38
# 234                Low   Clear       4.03         0.74             0.14
# 269                Low     NaN       4.74         0.99             0.39
# 282                Low   Clear       3.79         1.25             0.45
# 327             Medium   Clear       2.21         0.82             0.23
# 344                Low   Clear       4.62         1.86             0.43
# 357             Medium    Rain       2.03         0.91             0.19
# 366             Medium   Clear       4.20         1.09             0.18
# 401                Low   Clear       3.63         0.80             0.19
# 404               High    Rain       2.30         0.89             0.12
# 417                Low   Clear       4.00         1.87             0.15
# 424               High   Clear        NaN         1.42             0.48
# 428             Medium    Rain       3.84         1.55             0.41
# 438                Low    Rain       2.72         1.25             0.24
# 439             Medium     NaN       2.84         0.97             0.29
# 446             Medium   Clear       3.02         0.70             0.35
# 470               High   Clear       4.37         0.80             0.49
# 476                Low   Clear       2.15         1.62             0.47
# 584                Low   Clear       2.73         1.47             0.37
# 641                Low   Clear       3.08         0.70             0.38
# 647             Medium    Rain       3.46         0.83             0.47
# 725             Medium   Clear       3.88         1.96             0.32
# 734                Low   Clear       3.14          NaN             0.14
# 770             Medium   Clear       3.05         0.98             0.24
# 774             Medium   Clear       3.77         1.15             0.31
# 796                NaN   Clear       3.05         0.74             0.35
# 813               High    Snow       2.81         1.04             0.34
# 822             Medium   Clear       3.64         1.22             0.18
# 830                Low   Clear       2.11         0.82             0.40
# 839                Low   Clear       2.86         1.30             0.41
# 845                Low   Clear       2.22         0.90             0.40
# 846             Medium   Clear       2.82         1.18             0.42
# 872                Low   Clear       4.81         0.65             0.26
# 939                Low    Rain       3.59         0.69             0.27
# 943                Low    Snow       2.10         1.47             0.27
# 961             Medium   Clear       4.06         1.05             0.46
# 970               High   Clear       3.97         1.73             0.19
# 993             Medium   Clear       2.65         1.35              NaN
#
#      Trip_Duration_Minutes  Trip_Price
# 4                    22.64     15.6180
# 10                   26.34     14.8920
# 84                   58.31     45.8161
# 87                   92.72     57.9476
# 95                   67.43     60.0770
# 111                 109.77     37.3559
# 134                  38.26     85.6182
# 137                  57.56     73.5870
# 142                  36.68     44.7092
# 166                  86.31     51.9016
# 191                  80.70     76.1018
# 196                 115.73     89.0764
# 197                  72.79     77.1890
# 234                  49.37     18.7636
# 269                  24.57     29.5584
# 282                  40.52     46.2740
# 327                  42.84     37.4586
# 344                   7.19     45.8975
# 357                  12.42     31.4168
# 366                    NaN     66.1816
# 401                 109.95     60.7045
# 404                  74.77     26.1176
# 417                 100.36     51.0310
# 424                  23.11     19.2572
# 428                  19.20     39.9065
# 438                  49.77     59.1773
# 439                  41.04     19.5819
# 446                  94.88     70.7450
# 470                  18.39     14.6611
# 476                  42.81     29.7551
# 584                  42.88     65.6944
# 641                  27.81     25.3938
# 647                  51.82     56.2678
# 725                 111.65    122.4180
# 734                  89.47     34.4316
# 770                    NaN     19.0904
# 774                  87.74     77.0499
# 796                 105.71     74.5843
# 813                    NaN     66.8568
# 822                  75.87     38.4514
# 830                  85.00     45.9582
# 839                  58.01     68.2181
# 845                 119.82     69.3360
# 846                  91.53     47.3750
# 872                  10.76     28.7716
# 939                  87.25     47.3300
# 943                  48.69     76.4865
# 961                   7.26     39.4771
# 970                  58.48     73.0708
# 993                  25.61     55.3348

# %%
df[df['Per_Minute_Rate'].isnull()]
# Out:
#      Trip_Distance_km Time_of_Day Day_of_Week  Passenger_Count  \
# 6            3.850000   Afternoon     Weekday              4.0
# 39          22.570000   Afternoon     Weekday              1.0
# 89          24.140000     Morning     Weekday              2.0
# 125         21.930000   Afternoon         NaN              3.0
# 127         43.180000   Afternoon     Weekday              3.0
# 149         14.650000     Evening     Weekend              2.0
# 189         12.850000     Evening     Weekday              4.0
# 205          1.450000     Evening     Weekend              1.0
# 235         36.400000   Afternoon     Weekday              4.0
# 287        100.380420   Afternoon     Weekday              3.0
# 292         41.310000   Afternoon     Weekday              NaN
# 321         36.020000     Morning     Weekend              2.0
# 372          5.630000     Evening     Weekday              1.0
# 409          5.470000         NaN     Weekday              3.0
# 414         31.960000   Afternoon     Weekday              3.0
# 443         19.160000   Afternoon     Weekend              2.0
# 444         40.830000     Evening     Weekday              1.0
# 450         39.080000   Afternoon     Weekday              NaN
# 490         23.330000     Morning     Weekday              1.0
# 504         34.550000   Afternoon     Weekday              1.0
# 519          8.370000       Night     Weekend              3.0
# 522         48.530000   Afternoon     Weekday              1.0
# 549         38.840000   Afternoon     Weekday              1.0
# 566         20.220000   Afternoon     Weekday              1.0
# 583         17.110000   Afternoon     Weekday              NaN
# 585         12.770000     Morning     Weekday              3.0
# 617         14.570000   Afternoon     Weekday              4.0
# 618         40.500000   Afternoon     Weekend              3.0
# 621         11.260000     Morning     Weekend              3.0
# 627         37.630000   Afternoon     Weekday              2.0
# 706         16.800000   Afternoon     Weekday              4.0
# 745         45.080000   Afternoon     Weekend              2.0
# 747        101.039704         NaN     Weekday              1.0
# 753         17.410000     Morning     Weekday              NaN
# 778         36.280000         NaN     Weekday              2.0
# 783         17.940000   Afternoon         NaN              2.0
# 808         23.090000     Morning     Weekday              3.0
# 829         23.160000     Morning     Weekday              2.0
# 833          9.640000     Evening         NaN              4.0
# 855         10.340000     Morning     Weekday              1.0
# 883          6.100000     Evening     Weekday              3.0
# 904         21.650000     Evening     Weekday              3.0
# 909         19.600000     Morning     Weekday              3.0
# 935         14.340000     Evening     Weekday              1.0
# 962         13.020000     Evening     Weekday              1.0
# 967         15.560000   Afternoon     Weekday              2.0
# 985         25.280000     Morning     Weekend              3.0
# 993               NaN     Morning     Weekday              3.0
# 996         45.950000       Night     Weekday              4.0
# 997          7.700000     Morning     Weekday              3.0
#
#     Traffic_Conditions Weather  Base_Fare  Per_Km_Rate  Per_Minute_Rate  \
# 6                 High    Rain       3.51         1.66              NaN
# 39                 Low   Clear       3.40         1.41              NaN
# 89                 Low     NaN       3.92         1.69              NaN
# 125                Low     NaN       4.53         0.76              NaN
# 127               High   Clear       3.03         1.54              NaN
# 149               High   Clear       3.74         1.79              NaN
# 189                Low    Snow       3.94         0.61              NaN
# 205               High   Clear       2.80         1.73              NaN
# 235             Medium   Clear       4.05         1.34              NaN
# 287             Medium    Rain       4.46          NaN              NaN
# 292             Medium   Clear       4.90         1.10              NaN
# 321                Low   Clear       3.34         1.28              NaN
# 372                Low   Clear       3.88         1.43              NaN
# 409                Low   Clear       2.49         1.22              NaN
# 414               High   Clear       3.55         0.94              NaN
# 443                Low   Clear       4.64         0.57              NaN
# 444                Low    Rain       4.90         1.35              NaN
# 450                Low   Clear       2.44         1.63              NaN
# 490                Low    Snow       2.04         1.92              NaN
# 504                Low    Rain       2.47         1.03              NaN
# 519                Low    Rain       2.27         1.62              NaN
# 522             Medium    Snow       4.57         1.94              NaN
# 549                Low   Clear       4.81         1.23              NaN
# 566                Low   Clear       3.46         0.55              NaN
# 583             Medium     NaN       2.77         1.23              NaN
# 585                Low   Clear       3.37         0.53              NaN
# 617             Medium   Clear       4.97         0.60              NaN
# 618                Low    Rain       2.80         1.54              NaN
# 621             Medium    Rain       2.34         0.68              NaN
# 627               High   Clear       2.90         0.92              NaN
# 706             Medium    Rain       2.78         0.88              NaN
# 745               High   Clear       3.82         0.57              NaN
# 747                Low    Rain       4.39         1.79              NaN
# 753             Medium   Clear       2.05         1.86              NaN
# 778                Low    Rain       4.53         1.64              NaN
# 783                Low    Rain       4.14         1.43              NaN
# 808               High    Rain       3.58         1.68              NaN
# 829               High   Clear       2.16         1.36              NaN
# 833             Medium   Clear       3.53         1.28              NaN
# 855             Medium   Clear       4.91         1.64              NaN
# 883             Medium   Clear       2.74         1.34              NaN
# 904               High   Clear       2.18         1.05              NaN
# 909             Medium   Clear       4.82         1.40              NaN
# 935                Low    Rain       3.69         1.85              NaN
# 962               High   Clear       4.85         1.87              NaN
# 967                NaN    Rain       2.21         1.48              NaN
# 985             Medium    Snow       3.47         1.52              NaN
# 993             Medium   Clear       2.65         1.35              NaN
# 996             Medium   Clear       3.12         0.61              NaN
# 997                Low    Rain       2.08         1.78              NaN
#
#      Trip_Duration_Minutes  Trip_Price
# 6                     5.05   11.264500
# 39                  105.98   62.778500
# 89                   82.14   55.394800
# 125                  74.52   48.024000
# 127                 104.17   98.694800
# 149                  29.58   40.020700
# 189                  26.63   23.495700
# 205                  63.01   12.239600
# 235                 117.94   94.105000
# 287                  89.21  329.913004
# 292                  21.18   56.059600
# 321                 119.17   79.238100
# 372                  82.22   51.396500
# 409                 118.44   44.695400
# 414                  14.64   35.056400
# 443                 111.87   34.579100
# 444                  39.90   69.995500
# 450                  36.57   83.694000
# 490                  34.00   59.073600
# 504                    NaN   63.615000
# 519                  80.78   52.988200
# 522                  60.77  124.241600
# 549                  64.42   62.890400
# 566                  34.14   24.481600
# 583                  91.82   36.670100
# 585                  20.90   17.662100
# 617                 118.39   37.390000
# 618                 112.84   84.352800
# 621                  58.80   30.576800
# 627                  74.12   72.356000
# 706                  62.63   26.958500
# 745                 110.21   70.293300
# 747                  56.78  283.645201
# 753                  39.98         NaN
# 778                   7.73   66.039000
# 783                  15.13   33.274100
# 808                  23.94   48.835000
# 829                  98.11   62.109500
# 833                  87.39   39.464500
# 855                  95.63   43.862500
# 883                  48.23   32.135200
# 904                  24.22   31.694100
# 909                  63.47   48.127500
# 935                    NaN   38.035000
# 962                  89.60   48.013400
# 967                 109.57   59.205500
# 985                  76.73   73.354900
# 993                  25.61   55.334800
# 996                  61.96   62.129500
# 997                  54.18   33.123600

# %%
df['Trip_Distance_km'].fillna(df['Trip_Distance_km'].median(), inplace=True)

# %%
df.describe()
# Out:
#        Trip_Distance_km  Passenger_Count   Base_Fare  Per_Km_Rate  \
# count       1000.000000       950.000000  950.000000   950.000000
# mean          27.008520         2.476842    3.502989     1.233316
# std           19.402661         1.102249    0.870162     0.429816
# min            1.230000         1.000000    2.010000     0.500000
# 25%           13.107500         1.250000    2.730000     0.860000
# 50%           25.830000         2.000000    3.520000     1.220000
# 75%           37.782500         3.000000    4.260000     1.610000
# max          146.067047         4.000000    5.000000     2.000000
#
#        Per_Minute_Rate  Trip_Duration_Minutes  Trip_Price
# count       950.000000             950.000000  951.000000
# mean          0.292916              62.118116   56.874773
# std           0.115592              32.154406   40.469791
# min           0.100000               5.010000    6.126900
# 25%           0.190000              35.882500   33.742650
# 50%           0.290000              61.860000   50.074500
# 75%           0.390000              89.055000   69.099350
# max           0.500000             119.840000  332.043689

# %%
df['Passenger_Count'].fillna(df['Passenger_Count'].median(), inplace=True)
df['Base_Fare'].fillna(df['Base_Fare'].median(), inplace=True)
df['Per_Km_Rate'].fillna(df['Per_Km_Rate'].median(), inplace=True)
df['Per_Minute_Rate'].fillna(df['Per_Minute_Rate'].median(), inplace=True)
df['Trip_Duration_Minutes'].fillna(df['Trip_Duration_Minutes'].median(), inplace=True)
df['Trip_Price'].fillna(df['Trip_Price'].median(), inplace=True)

# %%
df.describe()
# Out:
#        Trip_Distance_km  Passenger_Count    Base_Fare  Per_Km_Rate  \
# count       1000.000000      1000.000000  1000.000000  1000.000000
# mean          27.008520         2.453000     3.503840     1.232650
# std           19.402661         1.079331     0.848115     0.418932
# min            1.230000         1.000000     2.010000     0.500000
# 25%           13.107500         2.000000     2.770000     0.870000
# 50%           25.830000         2.000000     3.520000     1.220000
# 75%           37.782500         3.000000     4.202500     1.580000
# max          146.067047         4.000000     5.000000     2.000000
#
#        Per_Minute_Rate  Trip_Duration_Minutes   Trip_Price
# count      1000.000000            1000.000000  1000.000000
# mean          0.292770              62.105210    56.541560
# std           0.112664              31.339464    39.492129
# min           0.100000               5.010000     6.126900
# 25%           0.197500              37.107500    34.578850
# 50%           0.290000              61.860000    50.074500
# 75%           0.382500              87.775000    67.476650
# max           0.500000             119.840000   332.043689

# %%
df['Time_of_Day'].fillna(df['Time_of_Day'].mode()[0], inplace=True)
df['Day_of_Week'].fillna(df['Day_of_Week'].mode()[0], inplace=True)
df['Traffic_Conditions'].fillna(df['Traffic_Conditions'].mode()[0], inplace=True)
df['Weather'].fillna(df['Weather'].mode()[0], inplace=True)

# %%
df['Time_of_Day'].mode()
# Out:
# 0    Afternoon
# Name: Time_of_Day, dtype: object

# %%
df['Weather'].mode()[0]
# Out:
# 'Clear'

# %%
df[df['Weather'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Trip_Distance_km, Time_of_Day, Day_of_Week, Passenger_Count, Traffic_Conditions, Weather, Base_Fare, Per_Km_Rate, Per_Minute_Rate, Trip_Duration_Minutes, Trip_Price]
# Index: []

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %%
X = df[['Trip_Distance_km']]
y = df['Trip_Price']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %%
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
mse = mean_squared_error(y_test,y_pred)

# %%
mse
# Out:
# 595.14247676801

# %%
np.sqrt(mse)
# Out:
# 24.39554214949957

# %%
# Scatterplot of actual data
plt.scatter(X, y, color='blue', label='Actual Data')

# Plot the regression line
plt.plot(X, model.predict(X), color='red', label='Regression Line')

# Plot errors (residuals)
for i in range(len(X)):
    plt.plot([X.iloc[i, 0], X.iloc[i, 0]], [y.iloc[i], model.predict(X)[i]], color='green', linestyle='dotted')

# Labels and title
plt.xlabel('Trip_Distance_km')
plt.ylabel('Trip_Price')
plt.title('Regression Line and Errors')
plt.legend()
plt.show()

# %%
df.to_excel('Abdate_Texi_Trib_Price.xlsx',index=False)
