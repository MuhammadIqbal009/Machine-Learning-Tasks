# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('loan_data.csv')

# %%
df
# Out:
#        person_age person_gender person_education  person_income  \
# 0            22.0        female           Master        71948.0
# 1            21.0        female      High School        12282.0
# 2            25.0        female      High School        12438.0
# 3            23.0        female         Bachelor        79753.0
# 4            24.0          male           Master        66135.0
# ...           ...           ...              ...            ...
# 44995        27.0          male        Associate        47971.0
# 44996        37.0        female        Associate        65800.0
# 44997        33.0          male        Associate        56942.0
# 44998        29.0          male         Bachelor        33164.0
# 44999        24.0          male      High School        51609.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT    35000.0           PERSONAL
# 1                   0                   OWN     1000.0          EDUCATION
# 2                   3              MORTGAGE     5500.0            MEDICAL
# 3                   0                  RENT    35000.0            MEDICAL
# 4                   1                  RENT    35000.0            MEDICAL
# ...               ...                   ...        ...                ...
# 44995               6                  RENT    15000.0            MEDICAL
# 44996              17                  RENT     9000.0    HOMEIMPROVEMENT
# 44997               7                  RENT     2771.0  DEBTCONSOLIDATION
# 44998               4                  RENT    12000.0          EDUCATION
# 44999               1                  RENT     6665.0  DEBTCONSOLIDATION
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 0              16.02                 0.49                         3.0
# 1              11.14                 0.08                         2.0
# 2              12.87                 0.44                         3.0
# 3              15.23                 0.44                         2.0
# 4              14.27                 0.53                         4.0
# ...              ...                  ...                         ...
# 44995          15.66                 0.31                         3.0
# 44996          14.07                 0.14                        11.0
# 44997          10.02                 0.05                        10.0
# 44998          13.23                 0.36                         6.0
# 44999          17.05                 0.13                         3.0
#
#        credit_score previous_loan_defaults_on_file  loan_status
# 0               561                             No            1
# 1               504                            Yes            0
# 2               635                             No            1
# 3               675                             No            1
# 4               586                             No            1
# ...             ...                            ...          ...
# 44995           645                             No            1
# 44996           621                             No            1
# 44997           668                             No            1
# 44998           604                             No            1
# 44999           628                             No            1
#
# [45000 rows x 14 columns]

# %%
df.describe()
# Out:
#          person_age  person_income  person_emp_exp     loan_amnt  \
# count  45000.000000   4.500000e+04    45000.000000  45000.000000
# mean      27.764178   8.031905e+04        5.410333   9583.157556
# std        6.045108   8.042250e+04        6.063532   6314.886691
# min       20.000000   8.000000e+03        0.000000    500.000000
# 25%       24.000000   4.720400e+04        1.000000   5000.000000
# 50%       26.000000   6.704800e+04        4.000000   8000.000000
# 75%       30.000000   9.578925e+04        8.000000  12237.250000
# max      144.000000   7.200766e+06      125.000000  35000.000000
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# count   45000.000000         45000.000000                45000.000000
# mean       11.006606             0.139725                    5.867489
# std         2.978808             0.087212                    3.879702
# min         5.420000             0.000000                    2.000000
# 25%         8.590000             0.070000                    3.000000
# 50%        11.010000             0.120000                    4.000000
# 75%        12.990000             0.190000                    8.000000
# max        20.000000             0.660000                   30.000000
#
#        credit_score   loan_status
# count  45000.000000  45000.000000
# mean     632.608756      0.222222
# std       50.435865      0.415744
# min      390.000000      0.000000
# 25%      601.000000      0.000000
# 50%      640.000000      0.000000
# 75%      670.000000      0.000000
# max      850.000000      1.000000

# %%
df['person_gender'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
df['person_education'].unique()
# Out:
# array(['Master', 'High School', 'Bachelor', 'Associate', 'Doctorate'],
#       dtype=object)

# %%
df['person_home_ownership'].unique()
# Out:
# array(['RENT', 'OWN', 'MORTGAGE', 'OTHER'], dtype=object)

# %%
df['loan_intent'].unique()
# Out:
# array(['PERSONAL', 'EDUCATION', 'MEDICAL', 'VENTURE', 'HOMEIMPROVEMENT',
#        'DEBTCONSOLIDATION'], dtype=object)

# %%
df['previous_loan_defaults_on_file'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
from sklearn.preprocessing import OrdinalEncoder

person_education_encoder = OrdinalEncoder(categories=[['Master', 'High School', 'Bachelor', 'Associate', 'Doctorate']])
df['person_education_Encoded'] = person_education_encoder.fit_transform(df[['person_education']])

df['person_gender_Encoded'] = df['person_gender'].map({'male': 0, 'female': 1})

person_home_ownership_encoder = OrdinalEncoder(categories=[['RENT', 'OWN', 'MORTGAGE', 'OTHER']])
df['person_home_ownership_Encoded'] = person_home_ownership_encoder.fit_transform(df[['person_home_ownership']])

loan_intent_encoder = OrdinalEncoder(categories=[['PERSONAL', 'EDUCATION', 'MEDICAL', 'VENTURE', 'HOMEIMPROVEMENT','DEBTCONSOLIDATION']])
df['loan_intent_Encoded'] = loan_intent_encoder.fit_transform(df[['loan_intent']])

df['previous_loan_defaults_on_file_Encoded'] = df['previous_loan_defaults_on_file'].map({'Yes': 1, 'No': 0})

# %%
df[['person_age','person_gender_Encoded','person_education_Encoded','person_income','person_home_ownership_Encoded','person_emp_exp','loan_amnt',
    'loan_int_rate','loan_percent_income','cb_person_cred_hist_length','loan_intent_Encoded','credit_score','previous_loan_defaults_on_file_Encoded',
    'loan_status']].corr()
# Out:
#                                         person_age  person_gender_Encoded  \
# person_age                                1.000000              -0.017528
# person_gender_Encoded                    -0.017528               1.000000
# person_education_Encoded                  0.052794              -0.003099
# person_income                             0.193698              -0.010173
# person_home_ownership_Encoded             0.037847              -0.001507
# person_emp_exp                            0.954412              -0.015078
# loan_amnt                                 0.050750              -0.010647
# loan_int_rate                             0.013402              -0.003662
# loan_percent_income                      -0.043299               0.000367
# cb_person_cred_hist_length                0.861985              -0.011999
# loan_intent_Encoded                       0.028694              -0.002883
# credit_score                              0.178432               0.000223
# previous_loan_defaults_on_file_Encoded   -0.025917              -0.000704
# loan_status                              -0.021476               0.000561
#
#                                         person_education_Encoded  \
# person_age                                              0.052794
# person_gender_Encoded                                  -0.003099
# person_education_Encoded                                1.000000
# person_income                                           0.002908
# person_home_ownership_Encoded                           0.003767
# person_emp_exp                                          0.048639
# loan_amnt                                               0.004241
# loan_int_rate                                          -0.000525
# loan_percent_income                                     0.007172
# cb_person_cred_hist_length                              0.052224
# loan_intent_Encoded                                     0.003583
# credit_score                                           -0.015531
# previous_loan_defaults_on_file_Encoded                  0.002373
# loan_status                                             0.001950
#
#                                         person_income  \
# person_age                                   0.193698
# person_gender_Encoded                       -0.010173
# person_education_Encoded                     0.002908
# person_income                                1.000000
# person_home_ownership_Encoded                0.216077
# person_emp_exp                               0.185987
# loan_amnt                                    0.242290
# loan_int_rate                                0.001510
# loan_percent_income                         -0.234177
# cb_person_cred_hist_length                   0.124316
# loan_intent_Encoded                          0.014983
# credit_score                                 0.035919
# previous_loan_defaults_on_file_Encoded       0.061483
# loan_status                                 -0.135808
#
#                                         person_home_ownership_Encoded  \
# person_age                                                   0.037847
# person_gender_Encoded                                       -0.001507
# person_education_Encoded                                     0.003767
# person_income                                                0.216077
# person_home_ownership_Encoded                                1.000000
# person_emp_exp                                               0.035354
# loan_amnt                                                    0.148561
# loan_int_rate                                               -0.129622
# loan_percent_income                                         -0.142674
# cb_person_cred_hist_length                                   0.028744
# loan_intent_Encoded                                          0.012976
# credit_score                                                 0.005715
# previous_loan_defaults_on_file_Encoded                       0.128954
# loan_status                                                 -0.239517
#
#                                         person_emp_exp  loan_amnt  \
# person_age                                    0.954412   0.050750
# person_gender_Encoded                        -0.015078  -0.010647
# person_education_Encoded                      0.048639   0.004241
# person_income                                 0.185987   0.242290
# person_home_ownership_Encoded                 0.035354   0.148561
# person_emp_exp                                1.000000   0.044589
# loan_amnt                                     0.044589   1.000000
# loan_int_rate                                 0.016631   0.146093
# loan_percent_income                          -0.039862   0.593011
# cb_person_cred_hist_length                    0.824272   0.042969
# loan_intent_Encoded                           0.020855   0.017300
# credit_score                                  0.186196   0.009074
# previous_loan_defaults_on_file_Encoded       -0.029231  -0.059009
# loan_status                                  -0.020481   0.107714
#
#                                         loan_int_rate  loan_percent_income  \
# person_age                                   0.013402            -0.043299
# person_gender_Encoded                       -0.003662             0.000367
# person_education_Encoded                    -0.000525             0.007172
# person_income                                0.001510            -0.234177
# person_home_ownership_Encoded               -0.129622            -0.142674
# person_emp_exp                               0.016631            -0.039862
# loan_amnt                                    0.146093             0.593011
# loan_int_rate                                1.000000             0.125209
# loan_percent_income                          0.125209             1.000000
# cb_person_cred_hist_length                   0.018008            -0.031868
# loan_intent_Encoded                          0.014161            -0.002695
# credit_score                                 0.011498            -0.011483
# previous_loan_defaults_on_file_Encoded      -0.181800            -0.203252
# loan_status                                  0.332005             0.384880
#
#                                         cb_person_cred_hist_length  \
# person_age                                                0.861985
# person_gender_Encoded                                    -0.011999
# person_education_Encoded                                  0.052224
# person_income                                             0.124316
# person_home_ownership_Encoded                             0.028744
# person_emp_exp                                            0.824272
# loan_amnt                                                 0.042969
# loan_int_rate                                             0.018008
# loan_percent_income                                      -0.031868
# cb_person_cred_hist_length                                1.000000
# loan_intent_Encoded                                       0.019566
# credit_score                                              0.155204
# previous_loan_defaults_on_file_Encoded                   -0.022640
# loan_status                                              -0.014851
#
#                                         loan_intent_Encoded  credit_score  \
# person_age                                         0.028694      0.178432
# person_gender_Encoded                             -0.002883      0.000223
# person_education_Encoded                           0.003583     -0.015531
# person_income                                      0.014983      0.035919
# person_home_ownership_Encoded                      0.012976      0.005715
# person_emp_exp                                     0.020855      0.186196
# loan_amnt                                          0.017300      0.009074
# loan_int_rate                                      0.014161      0.011498
# loan_percent_income                               -0.002695     -0.011483
# cb_person_cred_hist_length                         0.019566      0.155204
# loan_intent_Encoded                                1.000000      0.002044
# credit_score                                       0.002044      1.000000
# previous_loan_defaults_on_file_Encoded            -0.037213     -0.183005
# loan_status                                        0.073588     -0.007647
#
#                                         previous_loan_defaults_on_file_Encoded  \
# person_age                                                           -0.025917
# person_gender_Encoded                                                -0.000704
# person_education_Encoded                                              0.002373
# person_income                                                         0.061483
# person_home_ownership_Encoded                                         0.128954
# person_emp_exp                                                       -0.029231
# loan_amnt                                                            -0.059009
# loan_int_rate                                                        -0.181800
# loan_percent_income                                                  -0.203252
# cb_person_cred_hist_length                                           -0.022640
# loan_intent_Encoded                                                  -0.037213
# credit_score                                                         -0.183005
# previous_loan_defaults_on_file_Encoded                                1.000000
# loan_status                                                          -0.543096
#
#                                         loan_status
# person_age                                -0.021476
# person_gender_Encoded                      0.000561
# person_education_Encoded                   0.001950
# person_income                             -0.135808
# person_home_ownership_Encoded             -0.239517
# person_emp_exp                            -0.020481
# loan_amnt                                  0.107714
# loan_int_rate                              0.332005
# loan_percent_income                        0.384880
# cb_person_cred_hist_length                -0.014851
# loan_intent_Encoded                        0.073588
# credit_score                              -0.007647
# previous_loan_defaults_on_file_Encoded    -0.543096
# loan_status                                1.000000

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
X = df[["previous_loan_defaults_on_file_Encoded", "loan_percent_income","loan_int_rate","loan_amnt", "person_income","person_home_ownership_Encoded"]]
y = df["loan_status"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train[["previous_loan_defaults_on_file_Encoded","loan_percent_income","loan_int_rate","loan_amnt", "person_income","person_home_ownership_Encoded"]])
X_test_scaled=scaler.transform(X_test[["previous_loan_defaults_on_file_Encoded","loan_percent_income","loan_int_rate","loan_amnt", "person_income","person_home_ownership_Encoded"]])

# %%
model = LogisticRegression()
model.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression()

# %%
y_predict = model.predict(X_test_scaled)

# %%
print(y_test)
# Out:
# 40428    0
# 13410    0
# 27376    0
# 10889    0
# 22764    0
#         ..
# 15067    1
# 1302     1
# 3205     0
# 17679    0
# 20151    1
# Name: loan_status, Length: 9000, dtype: int64

# %%
print(y_predict)
# Out:
# [0 0 0 ... 0 0 1]

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
report  = classification_report(y_test, y_predict)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.93      0.93      7043
#            1       0.75      0.73      0.74      1957
#
#     accuracy                           0.89      9000
#    macro avg       0.84      0.83      0.83      9000
# weighted avg       0.89      0.89      0.89      9000

# %%
model.score(X_test_scaled, y_test)
# Out:
# 0.8874444444444445

# %%
confusion_matrix(y_test, y_predict)
# Out:
# array([[6567,  476],
#        [ 537, 1420]], dtype=int64)

# %%
cm = confusion_matrix(y_test, y_predict)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Class 0', 'Class 1'], yticklabels=['Class 0', 'Class 1'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
model.intercept_
# Out:
# array([-5.16592833])

# %%
model.coef_
# Out:
# array([[-4.38919542,  1.23026179,  0.96179235, -0.54779131,  0.0404888 ,
#         -0.37438504]])

# %%
from sklearn.metrics import roc_curve, auc

# Get predicted probabilities
y_probs = model.predict_proba(X_test_scaled)[:, 1]

# Compute ROC curve
fpr, tpr, _ = roc_curve(y_test, y_probs)
roc_auc = auc(fpr, tpr)

# Plot ROC Curve
plt.figure(figsize=(6, 4))
plt.plot(fpr, tpr, color="blue", label=f"ROC curve (AUC = {roc_auc:.2f})")
plt.plot([0, 1], [0, 1], color="gray", linestyle="--")  # Random model
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()
